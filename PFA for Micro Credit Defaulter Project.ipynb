# %% [markdown]
# # Dataset Information

# %% [markdown]
# This dataset is about Defaulter and Non-defaulter. The Consumer is believed to be defaulter if he deviates from the path of paying back the loaned amount within the time duration of 5 days.
# This dataset contains 209593 rows × 37 columns.

# %% [markdown]
# # Problem statement

# %% [markdown]
# A Microfinance Institution (MFI) is an organization that offers financial services to low income populations. From this dataset client and MFI want to know that there investment is profitable or not. They want to know some ideas so that they could improve in loan services and make profit. We will show them how can Defaulters be reduced. We will Build a model which can be used to predict in terms of a probability for each loan transaction, whether the customer will be paying back the loaned amount n 5 days of insurance of loan. Here '0' represent the defaulters and '1' represent the Non-defaulters.

# %% [markdown]
# # Dataset Features Information

# %% [markdown]
#  Variable   :  Definition
#
# 0. unamed:0 - this column is equal to index
#
# 1. label ---> Flag indicating whether the user paid back the credit amount within 5 days of issuing the loan{1:success, 0:failure}
#
# 2. msisdn	---> mobile number of user
#
# 3. aon	  ----> age on cellular network in days
#
# 4. daily_decr30 ---> Daily amount spent from main account, averaged over last 30 days (in Indonesian Rupiah)
#
# 5. daily_decr90 ---> Daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah)
#
# 6. rental30	---> Average main account balance over last 30 days
#
# 7. rental90	--->  Average main account balance over last 90 days
#
# 8. last_rech_date_ma ---> Number of days till last recharge of main account
#
# 9. last_rech_date_da ---> Number of days till last recharge of data account
#
# 10. last_rech_amt_ma	--> Amount of last recharge of main account (in Indonesian Rupiah)
#
# 11. cnt_ma_rech30 ---> Number of times main account got recharged in last 30 days
#
# 12. fr_ma_rech30 ---> Frequency of main account recharged in last 30 days
#
# 13. sumamnt_ma_rech30 ---> Total amount of recharge in main account over last 30 days (in Indonesian Rupiah)
#
# 14. medianamnt_ma_rech30-->Median of amount of recharges done in main account over last 30 days at user level (in Indonesian Rupiah)
#
# 15. medianmarechprebal30 ---> Median of main account balance just before recharge in last 30 days at user level (in Indonesian Rupiah)
#
# 16. cnt_ma_rech90	----> Number of times main account got recharged in last 90 days
#
# 17. fr_ma_rech90	----> Frequency of main account recharged in last 90 days
#
# 18. sumamnt_ma_rech90	---> Total amount of recharge in main account over last 90 days (in Indonasian Rupiah)
#
# 19. medianamnt_ma_rech90	---> Median of amount of recharges done in main account over last 90 days at user level (in Indonasian Rupiah)
#
# 20. medianmarechprebal90 --> Median of main account balance just before recharge in last 90 days at user level (in Indonasian Rupiah)
#
# 21. cnt_da_rech30	---> Number of times data account got recharged in last 30 days
#
# 22. fr_da_rech30	---> Frequency of data account recharged in last 30 days
#
# 23. cnt_da_rech90	----> Number of times data account got recharged in last 90 days
#
# 24. fr_da_rech90	---> Frequency of data account recharged in last 90 days
#
# 25. cnt_loans30	----> Number of loans taken by user in last 30 days
#
# 26. amnt_loans30	---> Total amount of loans taken by user in last 30 days
#
# 27. maxamnt_loans30	----> maximum amount of loan taken by the user in last 30 days
#
# 28. medianamnt_loans30	---> Median of amounts of loan taken by the user in last 30 days
#
# 29. cnt_loans90 ---->	Number of loans taken by user in last 90 days
#
# 30. amnt_loans90 ---> 	Total amount of loans taken by user in last 90 days
#
# 31. maxamnt_loans90	---> maximum amount of loan taken by the user in last 90 days
#
# 32. medianamnt_loans90	----> Median of amounts of loan taken by the user in last 90 days
#
# 33. payback30	---> Average payback time in days over last 30 days
#
# 34. payback90	---> Average payback time in days over last 90 days
#
# 35. pcircle	---> telecom circle
#
# 36. pdate	----> date

# %% [markdown]
# # Import Modules

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("C://Users//batha//Downloads//Micro-Credit-Project//Micro Credit Project//Data file.csv")
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %% [markdown]
# In above dataset Unnamed:0 column looks like index column so in coming step we would remove this column

# %%
df.shape
# Out:
# (209593, 37)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %% [markdown]
# # Data types of attributes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
# ...

# %% [markdown]
# Most of columns are numeric type and only three columns msisdn, pcircle and pdate are object type

# %% [markdown]
# # Statistical info

# %%
df.describe()
# Out:
#           Unnamed: 0          label            aon   daily_decr30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean   104797.000000       0.875177    8112.343445    5381.402289
# std     60504.431823       0.330519   75696.082531    9220.623400
# min         1.000000       0.000000     -48.000000     -93.012667
# 25%     52399.000000       1.000000     246.000000      42.440000
# 50%    104797.000000       1.000000     527.000000    1469.175667
# 75%    157195.000000       1.000000     982.000000    7244.000000
# max    209593.000000       1.000000  999860.755168  265926.000000
#
#         daily_decr90       rental30       rental90  last_rech_date_ma  \
# count  209593.000000  209593.000000  209593.000000      209593.000000
# mean     6082.515068    2692.581910    3483.406534        3755.847800
# std     10918.812767    4308.586781    5770.461279       53905.892230
# min       -93.012667  -23737.140000  -24720.580000         -29.000000
# ...

# %% [markdown]
# All columns have similar counts 209593 and it means there is no Nan or missing values in all above columns and that is realy good think.
#
# We can see that most of columns have large difference between mean and median that means most of columns are with outliers.
#
# Average payback time in days :- maximum is 171 days and minimum is 9 days in last 30 days.

# %% [markdown]
# # check unique values in the dataset¶

# %%
df.apply(lambda x: len(x.unique()))
# Out:
# Unnamed: 0              209593
# label                        2
# msisdn                  186243
# aon                       4507
# daily_decr30            147026
# daily_decr90            158670
# rental30                132148
# rental90                141033
# last_rech_date_ma         1186
# last_rech_date_da         1174
# last_rech_amt_ma            70
# cnt_ma_rech30               71
# fr_ma_rech30              1083
# sumamnt_ma_rech30        15141
# medianamnt_ma_rech30       510
# medianmarechprebal30     30428
# cnt_ma_rech90              110
# fr_ma_rech90                89
# sumamnt_ma_rech90        31771
# medianamnt_ma_rech90       608
# medianmarechprebal90     29785
# cnt_da_rech30             1066
# fr_da_rech30              1072
# cnt_da_rech90               27
# fr_da_rech90                46
# cnt_loans30                 40
# amnt_loans30                48
# maxamnt_loans30           1050
# medianamnt_loans30           6
# cnt_loans90               1110
# ...

# %% [markdown]
# from above observation it is clear that column of pcircle has only one unique value so we can remove this column.

# %% [markdown]
# # preprocessing the dataset

# %% [markdown]
# check null values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# ...

# %% [markdown]
# In this dataset there is no null values that is good think

# %% [markdown]
# check categoraical column

# %%
cat_col=[]
for x in df.dtypes.index:
    if df.dtypes[x]=='object':
        cat_col.append(x)
print("Total number of categorical columns are:-",len(cat_col))
cat_col
# Out:
# Total number of categorical columns are:- 3
# ['msisdn', 'pcircle', 'pdate']

# %% [markdown]
# only three columns are categoriacl and rest off are numerical. In this dataset pdate column is object type column so we would convert it into date type

# %% [markdown]
# convert pdate column into date type

# %%
df['pdate']=pd.to_datetime(df['pdate'])

# %%
df['pdate']
# Out:
# 0        2016-07-20
# 1        2016-08-10
# 2        2016-08-19
# 3        2016-06-06
# 4        2016-06-22
#             ...
# 209588   2016-06-17
# 209589   2016-06-12
# 209590   2016-07-29
# 209591   2016-07-25
# 209592   2016-07-07
# Name: pdate, Length: 209593, dtype: datetime64[ns]

# %% [markdown]
# Now pdate column has been convert into datetime column

# %% [markdown]
# # creation of new attributes

# %%
df['Year']=df['pdate'].apply(lambda x:x.year)
df['Month']=df['pdate'].apply(lambda x:x.month)
df['Day']=df['pdate'].apply(lambda x:x.day)

# %%
df.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    amnt_loans90  maxamnt_loans90  medianamnt_loans90  payback30  payback90  \
# 0            12                6                 0.0  29.000000  29.000000
# ...

# %% [markdown]
# we have extracted the column of pdate into Year,Month and Day so we can remove this column

# %%
df.Year.nunique()
# Out:
# 1

# %%
df['Year'].value_counts()
# Out:
# 2016    209593
# Name: Year, dtype: int64

# %% [markdown]
# Now we can say that in Year column there is only one unique value it mean all rows of Year column has 2016 only so we can remove this column

# %% [markdown]
# handle string value in 'msisdn' column

# %%
df["msisdn"]
# Out:
# 0         21408I70789
# 1         76462I70374
# 2         17943I70372
# 3         55773I70781
# 4         03813I82730
#              ...
# 209588    22758I85348
# 209589    95583I84455
# 209590    28556I85350
# 209591    59712I82733
# 209592    65061I85339
# Name: msisdn, Length: 209593, dtype: object

# %% [markdown]
# this column is object type and have a String "I" so we would replace the string 'I' from a number and convert it into numeric type.

# %%
df['msisdn'].replace("I",'1',regex=True,inplace=True)

# %%
df['msisdn']
# Out:
# 0         21408170789
# 1         76462170374
# 2         17943170372
# 3         55773170781
# 4         03813182730
#              ...
# 209588    22758185348
# 209589    95583184455
# 209590    28556185350
# 209591    59712182733
# 209592    65061185339
# Name: msisdn, Length: 209593, dtype: object

# %% [markdown]
# we have replaced the string with a number, now convert it into numeric type

# %%
df['msisdn']=df["msisdn"].astype(float)

# %% [markdown]
# # droping the columns

# %%
df.drop(columns=['Unnamed: 0','pcircle','Year','pdate'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    label        msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  2.140817e+10  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  7.646217e+10  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  1.794317e+10  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  5.577317e+10  241.0     21.228000     21.228000    159.42    159.42
# 4      1  3.813183e+09  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 0                2.0                0.0              1539  ...
# 1               20.0                0.0              5787  ...
# 2                3.0                0.0              1539  ...
# 3               41.0                0.0               947  ...
# 4                4.0                0.0              2309  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# ...

# %% [markdown]
# # target variable
#
# In this dataset our target variable is label which have two values 0 and 1, 1 means success or non-defaulter and 0 means failure or defaulter

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %% [markdown]
# univariate analysis

# %%
df1=df.copy()
df1['label']=df1['label'].map({0:'Defaulter',1:'Non-defaulter'})
print((df1.label.value_counts()/len(df1.index))*100)
sns.countplot(df1['label'])
# Out:
# Non-defaulter    87.517713
# Defaulter        12.482287
# Name: label, dtype: float64

# %% [markdown]
# From above observation it is clear that Defaulter are less than the Non-defaulter. Defaulters are 12.48% which are about 25000 and Non-defaulter are 87.51% which are about 185000.

# %%
sns.countplot(df['medianamnt_loans30'])
plt.title('Median of amounts of loan taken by the user in last 30 days')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
sns.countplot(df['medianamnt_loans90'])
plt.title('Median of amounts of loan taken by the user in last 90 days')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# bivariate analysis

# %%
plt.figure(figsize=(12,5))
sns.lineplot(x="Month", y="rental90", hue='label', data=df1)
plt.ylabel('main account balance',fontsize=20)
plt.xlabel('Month',fontsize=20)
plt.title('main account balance vs Month',fontsize=20)
plt.show()

# %% [markdown]
# from above observation it is clear that defaulters do not keep so much balance in main account rather than non-defaulters keep balance in their main account every month thus we can identify the defaulters basis on main account balance

# %%
plt.figure(figsize=(12,5))
sns.lineplot(x="Month", y="daily_decr90", hue='label', data=df1)
plt.ylabel('Daily amount spent from main account')
plt.xlabel('Month',fontsize=20)
plt.title('Daily amount spent from main account vs Month',fontsize=20)
plt.show()

# %% [markdown]
# from above observation it is clear that defaulters do spend more money on recharge on the monthly basis rather than non-defaulters spend so much money continuously on the recharge,thus we can identify the defaulters

# %%
plt.figure(figsize=(12,5))
sns.lineplot(x="Month", y="cnt_ma_rech90", hue='label', data=df1)
plt.ylabel('Numer of times got rechared',fontsize=15)
plt.xlabel('Month',fontsize=20)
plt.title('Numer of times got rechared vs Month',fontsize=20)
plt.show()

# %% [markdown]
# from above observation it is clear that defualters get recharge 1 or 2 times in a month but non-defaulters get recharge 3 to 5 times in a month so we can say that non-defaulters get recharge more times than the defaulters in a month, thus we can identify the defaulters

# %%
plt.figure(figsize=(12,5))
sns.lineplot(x="Month", y="sumamnt_ma_rech90", hue='label', data=df1)
plt.ylabel('Total amount of recharge in main account ')
plt.xlabel('Month',fontsize=20)
plt.title('Total amount of recharge in main account vs Month',fontsize=20)
plt.show()

# %% [markdown]
# from above graph it is clear that total amount of recharge in main account is too much higher in non-defaulters account than defaulters thus we can identify the defaulters

# %%
plt.figure(figsize=(12,5))
sns.lineplot(x="Month", y="cnt_loans90", hue='label', data=df1)
plt.ylabel('Number of loans taken by user',fontsize=15)
plt.xlabel('Month',fontsize=20)
plt.title("Number of loans taken by user vs Month",fontsize=20)
plt.show()

# %% [markdown]
# from above graph it is clear that frequency of loans taking is same for both so here is deficult to identify the defaulters.

# %%
plt.figure(figsize=(12,5))
sns.lineplot(x="Month", y="payback90", hue='label', data=df1)
plt.ylabel('Average payback time in days',fontsize=15)
plt.xlabel("Month",fontsize=20)
plt.title('Average payback time in days vs Month',fontsize=20)
plt.show()

# %% [markdown]
# from above graph it is clear that average payback time for defaulters is 2 to 5 days and for no-defaulters it is 3 to 6 days.

# %% [markdown]
# # correlation and heat map

# %%
plt.figure(figsize=(20,10)) 
sns.heatmap(df.corr(),cmap='YlOrRd_r',annot=True,linewidths=0.5,linecolor="black",fmt='.2f')

# %% [markdown]
#  columns which have positive correlation with target variable,are mentioned below:-
#
#     1. daily_decr30
#
#     2.daily_decr90
#
#     3. last_rech_amt_ma
#
#     4. cnt_ma_rech30
#
#     5. sumamnt_ma_rech90
#
#     6. medianamnt_ma_rech90
#
#     7. cnt_loans30
#
#     8. amnt_loans30
#
#     9. amnt_loans90
#
#     10. Month

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  float64
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
# ...

# %% [markdown]
# # checking outliers

# %%
df['msisdn'].plot.box()

# %% [markdown]
# we can see that msisdn column has no outliers

# %%
df['daily_decr30'].plot.box()

# %% [markdown]
# we can see that 'daily_decr30' column has outliers

# %%
fig, ax = plt.subplots(ncols=2, nrows=19, figsize=(15,30))
index=0
ax = ax.flatten()
for col, value in df.items():
    sns.boxplot(y=col, data=df, ax=ax[index])
    index += 1
plt.tight_layout(pad=1, w_pad=1, h_pad=5.0)

# %% [markdown]
# from above observation it is clear that most of columns have outliers except msisdn,Month and day. so we would remove the outliers

# %% [markdown]
# # Removing the outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
threshold=3
print(np.where(z>3))
df_new=df[(z<3).all(axis=1)]
# Out:
# (array([    21,     22,     22, ..., 209586, 209587, 209587], dtype=int64), array([16, 16, 33, ..., 29, 27, 31], dtype=int64))

# %%
df_new
# Out:
#         label        msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 0           0  2.140817e+10   272.0   3055.050000   3065.150000    220.13
# 1           1  7.646217e+10   712.0  12122.000000  12124.750000   3691.26
# 2           1  1.794317e+10   535.0   1398.000000   1398.000000    900.13
# 3           1  5.577317e+10   241.0     21.228000     21.228000    159.42
# 4           1  3.813183e+09   947.0    150.619333    150.619333   1098.90
# ...       ...           ...     ...           ...           ...       ...
# 209588      1  2.275819e+10   404.0    151.872333    151.872333   1089.19
# 209589      1  9.558318e+10  1075.0     36.936000     36.936000   1728.36
# 209590      1  2.855619e+10  1013.0  11843.111667  11904.350000   5861.83
# 209591      1  5.971218e+10  1732.0  12488.228333  12574.370000    411.83
# 209592      1  6.506119e+10  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# ...

# %%
df
# Out:
#         label        msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 0           0  2.140817e+10   272.0   3055.050000   3065.150000    220.13
# 1           1  7.646217e+10   712.0  12122.000000  12124.750000   3691.26
# 2           1  1.794317e+10   535.0   1398.000000   1398.000000    900.13
# 3           1  5.577317e+10   241.0     21.228000     21.228000    159.42
# 4           1  3.813183e+09   947.0    150.619333    150.619333   1098.90
# ...       ...           ...     ...           ...           ...       ...
# 209588      1  2.275819e+10   404.0    151.872333    151.872333   1089.19
# 209589      1  9.558318e+10  1075.0     36.936000     36.936000   1728.36
# 209590      1  2.855619e+10  1013.0  11843.111667  11904.350000   5861.83
# 209591      1  5.971218e+10  1732.0  12488.228333  12574.370000    411.83
# 209592      1  6.506119e+10  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# ...

# %% [markdown]
# # percentage loss of data while removing outliers:

# %%
percentage_loss=((209593-161465)/209593)*100
print(percentage_loss)
# Out:
# 22.962598941758554

# %% [markdown]
# we can see that we are losing data more than 8 % so we would go with outliers data

# %% [markdown]
# # model selection

# %% [markdown]
# input split

# %%
x=df.drop(columns=['label'],axis=1)
y=df['label']

# %% [markdown]
# # import module for model selection and spliting tha data

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale=StandardScaler()
x=scale.fit_transform(x)
x
# Out:
# array([[-0.98045659, -0.10357685, -0.25229941, ...,  2.39409346,
#          0.27336037,  0.6637208 ],
#        [ 0.9241541 , -0.09776412,  0.73103667, ..., -0.41923266,
#          1.62209905, -0.52127058],
#        [-1.10032939, -0.10010243, -0.43201111, ..., -0.41923266,
#          1.62209905,  0.54522166],
#        ...,
#        [-0.73316874, -0.09378769,  0.70079045, ..., -0.04735622,
#          0.27336037,  1.73021304],
#        [ 0.34468293, -0.08428915,  0.77075515, ...,  0.59938541,
#          0.27336037,  1.25621649],
#        [ 0.52973339, -0.08628398, -0.09674426, ..., -0.41923266,
#          0.27336037, -0.87676799]])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=45)

# %% [markdown]
# LogisticRegression

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
predlr=lr.predict(x_test)
print("Accuracy Score : ",accuracy_score(y_test,predlr))
print("\n Confusion Matrix : \n \n ",confusion_matrix(y_test,predlr))
print("\n Classification report : \n \n ",classification_report(y_test,predlr))
# Out:
# Accuracy Score :  0.8782719958361346
#
#  Confusion Matrix :
#
#   [[  178  5524]
#  [   89 40320]]
#
#  Classification report :
#
#                 precision    recall  f1-score   support
#
#            0       0.67      0.03      0.06      5702
#            1       0.88      1.00      0.93     40409
#
#     accuracy                           0.88     46111
#    macro avg       0.77      0.51      0.50     46111
# weighted avg       0.85      0.88      0.83     46111

# %% [markdown]
# we can see that errors are available in confussion matrix it means accuracy is not 100 %

# %% [markdown]
# GaussianNB

# %%
gnb=GaussianNB()
gnb.fit(x_train,y_train)
gnb.score(x_train,y_train)
predgnb=gnb.predict(x_test)
print("Accuracy Score :",accuracy_score(y_test,predgnb))
print("\n Confusion matrix : \n \n ",confusion_matrix(y_test,predgnb))
print("\n Classification report : \n \n  ",classification_report(y_test,predgnb))
# Out:
# Accuracy Score : 0.5905749170479929
#
#  Confusion matrix :
#
#   [[ 5003   699]
#  [18180 22229]]
#
#  Classification report :
#
#                  precision    recall  f1-score   support
#
#            0       0.22      0.88      0.35      5702
#            1       0.97      0.55      0.70     40409
#
#     accuracy                           0.59     46111
#    macro avg       0.59      0.71      0.52     46111
# weighted avg       0.88      0.59      0.66     46111

# %% [markdown]
# GaussionNB is not perfect modle for predicting beacause it has so many errors values than the LogisticRegression

# %% [markdown]
# DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print("Accuracy Score :",accuracy_score(y_test,preddtc))
print("\n Confusion matrix : \n \n ",confusion_matrix(y_test,preddtc))
print("\n Classification report : \n \n  ",classification_report(y_test,preddtc))
# Out:
# Accuracy Score : 0.8837153824467047
#
#  Confusion matrix :
#
#   [[ 3138  2564]
#  [ 2798 37611]]
#
#  Classification report :
#
#                  precision    recall  f1-score   support
#
#            0       0.53      0.55      0.54      5702
#            1       0.94      0.93      0.93     40409
#
#     accuracy                           0.88     46111
#    macro avg       0.73      0.74      0.74     46111
# weighted avg       0.89      0.88      0.88     46111

# %% [markdown]
# DecisionTreeClassifier is best model for predicting because it has less errors values and high accuracy than the above model

# %% [markdown]
# RandomForestClassifier

# %%
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
rfc.score(x_train,y_train)
predrfc=rfc.predict(x_test)
print("Accuracy Score :",accuracy_score(y_test,predrfc))
print("\n Confusion matrix : \n \n ",confusion_matrix(y_test,predrfc))
print("\n Classification report : \n \n  ",classification_report(y_test,predrfc))
# Out:
# Accuracy Score : 0.9229034286829607
#
#  Confusion matrix :
#
#   [[ 2906  2796]
#  [  759 39650]]
#
#  Classification report :
#
#                  precision    recall  f1-score   support
#
#            0       0.79      0.51      0.62      5702
#            1       0.93      0.98      0.96     40409
#
#     accuracy                           0.92     46111
#    macro avg       0.86      0.75      0.79     46111
# weighted avg       0.92      0.92      0.92     46111

# %% [markdown]
# RandomForestClassifier is best model for predicting than above models because it has less errors values and high accuracy than the other model so we would save this model for the predicting.

# %% [markdown]
# # Roc-Aoc cureve

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
roc_auc=roc_auc_score(y_test,predrfc)
fpr,tpr,threshold=roc_curve(y_test,predrfc)

# %%
plt.figure(figsize=(12,5))
plt.plot(fpr,tpr,label="rfc (area=%0.2f)"% roc_auc)
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.05,1.05])
plt.ylim([-0.05,1.05])
plt.xlabel('False Positive Rate',fontsize=20)
plt.ylabel('True Positive Rate',fontsize=20)
plt.title('Reciver operating characteristic',fontsize=20)
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # Save the Result in csv file

# %%
df_pred=pd.DataFrame(predrfc)
df_pred.to_csv('loans_predict.csv')

# %%
df1=pd.read_csv('loans_predict.csv')
df1
# Out:
#        Unnamed: 0  0
# 0               0  1
# 1               1  0
# 2               2  1
# 3               3  1
# 4               4  0
# ...           ... ..
# 46106       46106  1
# 46107       46107  1
# 46108       46108  1
# 46109       46109  1
# 46110       46110  1
#
# [46111 rows x 2 columns]

# %% [markdown]
# # conclusion

# %%
model_comparison=pd.DataFrame({'Model_Name':['LogisticRegression','GaussianNB','DecisionTreeClassifier','RandomForestClassifier'],
                               'Accuracy Score':[0.87,0.59,0.88,0.92]})
model_comparison
# Out:
#                Model_Name  Accuracy Score
# 0      LogisticRegression            0.87
# 1              GaussianNB            0.59
# 2  DecisionTreeClassifier            0.88
# 3  RandomForestClassifier            0.92

# %% [markdown]
# # Serialization

# %% [markdown]
# RandomForestClassifier is the best modle so we would save this model for predicting

# %%
import joblib
joblib.dump(RandomForestClassifier(),"microloansproject.pkl")
# Out:
# ['microloansproject.pkl']
