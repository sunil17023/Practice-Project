# %% [markdown]
# # Dataset information

# %% [markdown]
# This dataset contains complete information about  rapes crimes happened in India from 2001. There are many factors that can be analyzed from this dataset. this dataset helps us to understand better about India.

# %% [markdown]
# # dataset attribut information

# %% [markdown]
# Area_Name
#
# Year
#
# Subgroup
#
# Rape_Cases_Reported
#
# Victims_Above_50_Yrs
#
# Victims_Between_10-14_Yrs
#
# Victims_Between_14-18_Yrs
# Victims_Between_18-30_Yrs
#
# Victims_Between_30-50_Yrs
# Victims_of_Rape_Total
# Victims_Upto_10_Yrs

# %% [markdown]
# # import module

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns 
import matplotlib.style as stylle

# %% [markdown]
# # loading dataset

# %%
df=pd.read_csv("C:\\Users\\batha\\Downloads\\20_Victims_of_rape.csv")
df
# Out:
#                       Area_Name  Year                Subgroup  \
# 0     Andaman & Nicobar Islands  2001      Total Rape Victims
# 1     Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2     Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3     Andaman & Nicobar Islands  2002      Total Rape Victims
# 4     Andaman & Nicobar Islands  2002  Victims of Incest Rape
# ...                         ...   ...                     ...
# 1045                West Bengal  2009  Victims of Incest Rape
# 1046                West Bengal  2009   Victims of Other Rape
# 1047                West Bengal  2010      Total Rape Victims
# 1048                West Bengal  2010  Victims of Incest Rape
# 1049                West Bengal  2010   Victims of Other Rape
#
#       Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                       3                     0                          0
# ...

# %%
df.head()
# Out:
#                    Area_Name  Year                Subgroup  \
# 0  Andaman & Nicobar Islands  2001      Total Rape Victims
# 1  Andaman & Nicobar Islands  2001  Victims of Incest Rape
# 2  Andaman & Nicobar Islands  2001   Victims of Other Rape
# 3  Andaman & Nicobar Islands  2002      Total Rape Victims
# 4  Andaman & Nicobar Islands  2002  Victims of Incest Rape
#
#    Rape_Cases_Reported  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0                    3                     0                          0
# 1                    1                     0                          0
# 2                    2                     0                          0
# 3                    2                     0                          0
# 4                    0                     0                          0
#
#    Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 0                          3                          0
# 1                          1                          0
# ...

# %%
df.shape
# Out:
# (1050, 11)

# %% [markdown]
# this dataset has 1050 rows and 11 columns

# %%
df.columns
# Out:
# Index(['Area_Name', 'Year', 'Subgroup', 'Rape_Cases_Reported',
#        'Victims_Above_50_Yrs', 'Victims_Between_10-14_Yrs',
#        'Victims_Between_14-18_Yrs', 'Victims_Between_18-30_Yrs',
#        'Victims_Between_30-50_Yrs', 'Victims_of_Rape_Total',
#        'Victims_Upto_10_Yrs'],
#       dtype='object')

# %%
df['Subgroup'].value_counts()
# Out:
# Total Rape Victims        350
# Victims of Incest Rape    350
# Victims of Other Rape     350
# Name: Subgroup, dtype: int64

# %%
df.dtypes
# Out:
# Area_Name                    object
# Year                          int64
# Subgroup                     object
# Rape_Cases_Reported           int64
# Victims_Above_50_Yrs          int64
# Victims_Between_10-14_Yrs     int64
# Victims_Between_14-18_Yrs     int64
# Victims_Between_18-30_Yrs     int64
# Victims_Between_30-50_Yrs     int64
# Victims_of_Rape_Total         int64
# Victims_Upto_10_Yrs           int64
# dtype: object

# %%
df['Area_Name'].unique()
# Out:
# array(['Andaman & Nicobar Islands', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra & Nagar Haveli', 'Daman & Diu', 'Delhi', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Lakshadweep', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Odisha', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'West Bengal'], dtype=object)

# %%
df['Subgroup'].unique()
# Out:
# array(['Total Rape Victims', 'Victims of Incest Rape',
#        'Victims of Other Rape'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Area_Name                    0
# Year                         0
# Subgroup                     0
# Rape_Cases_Reported          0
# Victims_Above_50_Yrs         0
# Victims_Between_10-14_Yrs    0
# Victims_Between_14-18_Yrs    0
# Victims_Between_18-30_Yrs    0
# Victims_Between_30-50_Yrs    0
# Victims_of_Rape_Total        0
# Victims_Upto_10_Yrs          0
# dtype: int64

# %% [markdown]
# there is no null value in this dataset

# %% [markdown]
# # target variable

# %% [markdown]
# Victims_of_Rape_Total

# %% [markdown]
# # EDA

# %% [markdown]
# # scatterplot

# %%
sns.scatterplot(x="Year",y="Victims_of_Rape_Total",data=df)

# %% [markdown]
# from thr above observation it is clear that victims of rape case are increasing year by year

# %%
sns.scatterplot(x="Year",y="Rape_Cases_Reported",data=df)

# %% [markdown]
# from thr above observation it is clear that numbers of reported rape cases are increasing year by year

# %% [markdown]
# # countplot

# %%
sns.countplot(df["Subgroup"])
plt.title("Subgroup")
plt.show()

# %% [markdown]
# Victims of Other Rape  =   350
#
# Total Rape Victims     =   350
#
# Victims of Incest Rape  =  350

# %% [markdown]
# # state wise total victims of rape case

# %%
a=df.groupby(['Area_Name'])['Victims_of_Rape_Total'].sum().sort_values(ascending=False).reset_index()
a
# Out:
#                     Area_Name  Victims_of_Rape_Total
# 0              Madhya Pradesh                  58514
# 1                 West Bengal                  32756
# 2               Uttar Pradesh                  30106
# 3                 Maharashtra                  29010
# 4                       Assam                  25524
# 5                   Rajasthan                  23908
# 6                       Bihar                  22526
# 7              Andhra Pradesh                  21392
# 8                Chhattisgarh                  19502
# 9                      Odisha                  17720
# 10                  Jharkhand                  15126
# 11                 Tamil Nadu                  11098
# 12                     Kerala                  10616
# 13                      Delhi                  10342
# 14                    Haryana                  10018
# 15                     Punjab                   8614
# 16                  Karnataka                   7834
# ...

# %% [markdown]
# most of victims of rape case are from madhya pradesh and few are from Lakshdweep

# %%
plt.bar('Area_Name', 'Victims_of_Rape_Total',data=a,color="blue")
plt.rcParams['figure.figsize']=(15,6)
plt.xlabel("Area_Name",fontsize=20)
plt.ylabel("Victims_of_Rape_Total",fontsize=20)
plt.title("Rape cases state wise")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# from above observation we can say that in rape case madhya pradesh is on first place and second is west Bengal

# %%
b=df.groupby(['Year'])['Victims_of_Rape_Total'].sum().reset_index()
b
# Out:
#    Year  Victims_of_Rape_Total
# 0  2001                  32156
# 1  2002                  32756
# 2  2003                  31712
# 3  2004                  36478
# 4  2005                  36752
# 5  2006                  38730
# 6  2007                  41542
# 7  2008                  42970
# 8  2009                  42826
# 9  2010                  44386

# %% [markdown]
# # Year wise victims

# %%
plt.bar('Year', 'Victims_of_Rape_Total',data=b,color="blue")
plt.xlabel("Year",fontsize=20)
plt.ylabel("Victims_of_Rape_Total",fontsize=20)
plt.title("Rape cases year wise")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # year wise different ages group victims

# %%
import warnings
warnings.filterwarnings('ignore')
year =df.groupby(['Year'])['Victims_Above_50_Yrs','Victims_Between_10-14_Yrs','Victims_Between_14-18_Yrs','Victims_Between_18-30_Yrs','Victims_Between_30-50_Yrs'].sum().reset_index()
year
# Out:
#    Year  Victims_Above_50_Yrs  Victims_Between_10-14_Yrs  \
# 0  2001                   136                       2880
# 1  2002                   132                       1708
# 2  2003                   120                       1862
# 3  2004                   162                       2180
# 4  2005                   222                       2348
# 5  2006                   188                       2162
# 6  2007                   266                       2710
# 7  2008                   272                       2662
# 8  2009                   190                       3520
# 9  2010                   272                       2808
#
#    Victims_Between_14-18_Yrs  Victims_Between_18-30_Yrs  \
# 0                       7822                      15762
# 1                       2650                      21460
# 2                       3584                      19746
# 3                       4008                      22686
# ...

# %% [markdown]
# from the above observation it is clear that in every year most of rape case victims are between 18 to 30 years.

# %%
Area_name=df.groupby(['Area_Name'])['Victims_Above_50_Yrs','Victims_Between_10-14_Yrs','Victims_Between_14-18_Yrs','Victims_Between_18-30_Yrs','Victims_Between_30-50_Yrs'].sum().reset_index()
Area_name
# Out:
#                     Area_Name  Victims_Above_50_Yrs  \
# 0   Andaman & Nicobar Islands                     0
# 1              Andhra Pradesh                   198
# 2           Arunachal Pradesh                     0
# 3                       Assam                   190
# 4                       Bihar                    78
# 5                  Chandigarh                     0
# 6                Chhattisgarh                   226
# 7        Dadra & Nagar Haveli                     0
# 8                 Daman & Diu                     0
# 9                       Delhi                    26
# 10                        Goa                    10
# 11                    Gujarat                    16
# 12                    Haryana                    62
# 13           Himachal Pradesh                    36
# 14            Jammu & Kashmir                    12
# 15                  Jharkhand                    20
# 16                  Karnataka                    68
# ...

# %% [markdown]
# Madhya pradesh is on top in rape cases

# %% [markdown]
# # state wise total victims from 2001 to 2010

# %%
c=df.groupby(['Area_Name','Year'])['Victims_of_Rape_Total'].sum().reset_index()
c
# Out:
#                      Area_Name  Year  Victims_of_Rape_Total
# 0    Andaman & Nicobar Islands  2001                      6
# 1    Andaman & Nicobar Islands  2002                      4
# 2    Andaman & Nicobar Islands  2003                      4
# 3    Andaman & Nicobar Islands  2004                     20
# 4    Andaman & Nicobar Islands  2005                      8
# ..                         ...   ...                    ...
# 345                West Bengal  2006                   3462
# 346                West Bengal  2007                   4212
# 347                West Bengal  2008                   4526
# 348                West Bengal  2009                   4672
# 349                West Bengal  2010                   4622
#
# [350 rows x 3 columns]

# %%
Andman_and_nicobar= c[0:10]
Andman_and_nicobar
# Out:
#                    Area_Name  Year  Victims_of_Rape_Total
# 0  Andaman & Nicobar Islands  2001                      6
# 1  Andaman & Nicobar Islands  2002                      4
# 2  Andaman & Nicobar Islands  2003                      4
# 3  Andaman & Nicobar Islands  2004                     20
# 4  Andaman & Nicobar Islands  2005                      8
# 5  Andaman & Nicobar Islands  2006                     12
# 6  Andaman & Nicobar Islands  2007                      6
# 7  Andaman & Nicobar Islands  2008                     24
# 8  Andaman & Nicobar Islands  2009                     36
# 9  Andaman & Nicobar Islands  2010                     48

# %%
madhya_pradesh= c[190:200]
madhya_pradesh
# Out:
#           Area_Name  Year  Victims_of_Rape_Total
# 190  Madhya Pradesh  2001                   5702
# 191  Madhya Pradesh  2002                   5782
# 192  Madhya Pradesh  2003                   5476
# 193  Madhya Pradesh  2004                   5750
# 194  Madhya Pradesh  2005                   5842
# 195  Madhya Pradesh  2006                   5800
# 196  Madhya Pradesh  2007                   6020
# 197  Madhya Pradesh  2008                   5874
# 198  Madhya Pradesh  2009                   5996
# 199  Madhya Pradesh  2010                   6272

# %%
sns.barplot(x='Year',y='Victims_of_Rape_Total',data=madhya_pradesh)
plt.xlabel("Year",fontsize=20)
plt.ylabel("Victims_of_Rape_Total",fontsize=20)
plt.title("Rape cases in Madhya Pradesh year wisel",fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %%
west_bengal=c[340:351]
west_bengal
# Out:
#        Area_Name  Year  Victims_of_Rape_Total
# 340  West Bengal  2001                   1418
# 341  West Bengal  2002                   1518
# 342  West Bengal  2003                   2004
# 343  West Bengal  2004                   2950
# 344  West Bengal  2005                   3372
# 345  West Bengal  2006                   3462
# 346  West Bengal  2007                   4212
# 347  West Bengal  2008                   4526
# 348  West Bengal  2009                   4672
# 349  West Bengal  2010                   4622

# %%
plt.bar('Year', 'Victims_of_Rape_Total',data=west_bengal,color="red")
plt.xlabel("Year",fontsize=20)
plt.ylabel("Victims_of_Rape_Total",fontsize=20)
plt.title("Rape cases in West Benga year wisel",fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %%
uttar_pradesh=c[320:330]
uttar_pradesh
# Out:
#          Area_Name  Year  Victims_of_Rape_Total
# 320  Uttar Pradesh  2001                   3916
# 321  Uttar Pradesh  2002                   2830
# 322  Uttar Pradesh  2003                   1822
# 323  Uttar Pradesh  2004                   2794
# 324  Uttar Pradesh  2005                   2434
# 325  Uttar Pradesh  2006                   2628
# 326  Uttar Pradesh  2007                   3296
# 327  Uttar Pradesh  2008                   3742
# 328  Uttar Pradesh  2009                   3518
# 329  Uttar Pradesh  2010                   3126

# %%
plt.bar('Year', 'Victims_of_Rape_Total',data=uttar_pradesh,color="orange")
plt.xlabel("Year",fontsize=20)
plt.ylabel("Victims_of_Rape_Total",fontsize=20)
plt.title("Rape cases in uttar_pradesh year wisel",fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x='Year', y='Victims_of_Rape_Total',data=uttar_pradesh)
plt.xlabel("Year",fontsize=20)
plt.ylabel("Victims_of_Rape_Total",fontsize=20)
plt.title("Rape cases in uttar_pradesh year wisel",fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # describe and heatmap

# %%
df.describe()
# Out:
#              Year  Rape_Cases_Reported  Victims_Above_50_Yrs  \
# count  1050.00000          1050.000000           1050.000000
# mean   2005.50000           361.920000              1.866667
# std       2.87365           592.180572              4.640286
# min    2001.00000             0.000000              0.000000
# 25%    2003.00000             4.000000              0.000000
# 50%    2005.50000            37.000000              0.000000
# 75%    2008.00000           527.500000              1.000000
# max    2010.00000          3135.000000             43.000000
#
#        Victims_Between_10-14_Yrs  Victims_Between_14-18_Yrs  \
# count                1050.000000                1050.000000
# mean                   23.657143                  53.085714
# std                    50.677418                 115.127899
# min                     0.000000                   0.000000
# 25%                     0.000000                   0.000000
# ...

# %%
plt.figure(figsize=(15,8))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variables summary")
plt.show()

# %% [markdown]
# there is so far difference between mean and std so its mean there are outliers

# %% [markdown]
# # box plot - check outliers

# %%
plt.figure(figsize=(18,14))
box = sns.boxplot(data=df)
box.set_xticklabels(labels=box.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Year'),
#  Text(0, 0, 'Rape_Cases_Reported'),
#  Text(0, 0, 'Victims_Above_50_Yrs'),
#  Text(0, 0, 'Victims_Between_10-14_Yrs'),
#  Text(0, 0, 'Victims_Between_14-18_Yrs'),
#  Text(0, 0, 'Victims_Between_18-30_Yrs'),
#  Text(0, 0, 'Victims_Between_30-50_Yrs'),
#  Text(0, 0, 'Victims_of_Rape_Total'),
#  Text(0, 0, 'Victims_Upto_10_Yrs')]

# %% [markdown]
# most of the columns have outliers

# %%
df.skew()
# Out:
# Year                         0.000000
# Rape_Cases_Reported          2.228595
# Victims_Above_50_Yrs         4.151161
# Victims_Between_10-14_Yrs    3.554447
# Victims_Between_14-18_Yrs    3.327417
# Victims_Between_18-30_Yrs    2.089371
# Victims_Between_30-50_Yrs    2.905033
# Victims_of_Rape_Total        2.226962
# Victims_Upto_10_Yrs          2.845238
# dtype: float64

# %% [markdown]
# our data is skewed

# %% [markdown]
# # removing outliers ---> for this we should left the object type columns

# %%
df_new=df.drop(["Area_Name","Subgroup"],axis=1)
df_new
# Out:
#       Year  Rape_Cases_Reported  Victims_Above_50_Yrs  \
# 0     2001                    3                     0
# 1     2001                    1                     0
# 2     2001                    2                     0
# 3     2002                    2                     0
# 4     2002                    0                     0
# ...    ...                  ...                   ...
# 1045  2009                    3                     0
# 1046  2009                 2333                     0
# 1047  2010                 2311                     0
# 1048  2010                    4                     0
# 1049  2010                 2307                     0
#
#       Victims_Between_10-14_Yrs  Victims_Between_14-18_Yrs  \
# 0                             0                          3
# 1                             0                          1
# 2                             0                          2
# 3                             0                          1
# ...

# %%
from scipy.stats import zscore
import numpy as np
z= np.abs(zscore(df_new))
threshold=3
df_new1=df_new[(z<3).all(axis=1)]

# %%
print("Original shape= ",df_new.shape, "\n new shape= ",df_new1.shape)
# Out:
# Original shape=  (1050, 9)
#  new shape=  (963, 9)

# %% [markdown]
# # preparing dataset for model training¶

# %%
x=df_new1.drop("Victims_of_Rape_Total",axis=1)
y=df_new1['Victims_of_Rape_Total']

# %% [markdown]
# # scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
scaledX=sc.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score

best_rstate=0
accu=0
for i in range(30,200):
    x_train,x_test,y_train,y_test=train_test_split(scaledX,y,test_size=.25,random_state=i)
    mod=LinearRegression()
    mod.fit(x_train,y_train)
    y_pred=mod.predict(x_test)
    tempaccu=r2_score(y_test,y_pred)
    if tempaccu>accu:
        accu=tempaccu
        best_rstate=i
        
print(f"Best accuracy {accu*100} found on random_state {best_rstate}")
# Out:
# Best accuracy 100.0 found on random_state 30

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(scaledX,y,test_size=.25,random_state=128)

# %% [markdown]
# # finding the best model

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(x_train,y_train)
y_pred=LR.predict(x_test)
r2score=r2_score(y_test,y_pred)
cvscore=cross_val_score(LinearRegression(),x_train,y_train,cv=5).mean()
print(f"Accuracy= {r2score*100}, Cross_val_score = {cvscore*100} & difference = {(r2score*100)-(cvscore*100)}")
# Out:
# Accuracy= 100.0, Cross_val_score = 100.0 & difference = 0.0

# %%
from sklearn.ensemble import RandomForestRegressor
RF=RandomForestRegressor()
RF.fit(x_train,y_train)
y_pred=RF.predict(x_test)
r2score=r2_score(y_test,y_pred)
cvscore=cross_val_score(RandomForestRegressor(),x_train,y_train,cv=5).mean()
print(f"Accuracy= {r2score*100}, Cross_val_score = {cvscore*100} & difference = {(r2score*100)-(cvscore*100)}")
# Out:
# Accuracy= 99.96914768773676, Cross_val_score = 99.89646295730724 & difference = 0.07268473042952905

# %%
from sklearn.linear_model import SGDRegressor
SGD=SGDRegressor()
SGD.fit(x_train,y_train)
y_pred=SGD.predict(x_test)
r2score=r2_score(y_test,y_pred)
cvscore=cross_val_score(SGDRegressor(),x_train,y_train,cv=5).mean()
print(f"Accuracy= {r2score*100}, Cross_val_score = {cvscore*100} & difference = {(r2score*100)-(cvscore*100)}")
# Out:
# Accuracy= 99.99996325059888, Cross_val_score = 99.99990106249295 & difference = 6.218810592883983e-05

# %% [markdown]
# best accuracy model is LinearRegression so we save it

# %% [markdown]
# # Serialization

# %%
import joblib
joblib.dump(LinearRegression,"victimsofrape.pkl")
# Out:
# ['victimsofrape.pkl']
