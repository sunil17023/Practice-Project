# %% [markdown]
# # problem statement
#
# In this dataset we will try to find the reason "Why HR Employees left their jobs" and what are the main reasons
#
# Definition --->  HR analytics is the process of collecting and analyzing Human Resource (HR) data in order to improve an organization’s workforce performance.

# %% [markdown]
# # dataset information

# %% [markdown]
# It has 1,470 data points (rows) and 35 features (columns) describing each employee’s background and characteristics; and labelled (supervised learning) with whether they are still in the company or whether they have gone to work somewhere else.

# %% [markdown]
# # dataset's attributes

# %% [markdown]
#  0   Age
#  1   Attrition
#  2   BusinessTravel
#  3   DailyRate
#  4   Department
#  5   DistanceFromHome
#  6   Education
#  7   EducationField
#  8   EmployeeCount
#  9   EmployeeNumber
#  10  EnvironmentSatisfaction
#  11  Gender
#  12  HourlyRate
#  13  JobInvolvement
#  14  JobLevel
#  15  JobRole
#  16  JobSatisfaction
#  17  MaritalStatus
#  18  MonthlyIncome
#  19  MonthlyRate
#  20  NumCompaniesWorked
#  21  Over18
#  22  OverTime
#  23  PercentSalaryHike
#  24  PerformanceRating
#  25  RelationshipSatisfaction
#  26  StandardHours
#  27  StockOptionLevel
#  28  TotalWorkingYears
#  29  TrainingTimesLastYear
#  30  WorkLifeBalance
#  31  YearsAtCompany
#  32  YearsInCurrentRole
#  33  YearsSinceLastPromotion
#  34  YearsWithCurrManager

# %% [markdown]
# # loading the modules

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # loading the dataset

# %%
df=pd.read_csv("C:\\Users\\batha\\Downloads\\ibm-hr-analytics-employee-attrition-performance (2).zip")
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# this dataset has 1470 rows and 35 columns

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
#  data type of attributes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# # statistical info¶

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# HR employees are getting hourly minimum 30 dolar and  maximum  100 .

# %% [markdown]
# # check unique values in the dataset¶

# %%
df.apply(lambda x: len(x.unique()))
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %% [markdown]
# # preprocessing the dataset¶

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# this dataset has no missing values

# %% [markdown]
# check for categorical attributes

# %%
cat_col=[]
for x in df.dtypes.index:
    if df.dtypes[x]=='object':
        cat_col.append(x)
        
print("Total number of categorical columns are:- ",len(cat_col))
cat_col
# Out:
# Total number of categorical columns are:-  9
# ['Attrition',
#  'BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus',
#  'Over18',
#  'OverTime']

# %% [markdown]
# chect for numeriacl columns

# %%
num_col=[]
for y in df.dtypes.index:
    if df.dtypes[y]=="int64":
        num_col.append(y)

print("Total number of numerical columns are:- ",len(num_col))
num_col
# Out:
# Total number of numerical columns are:-  26
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'Education',
#  'EmployeeCount',
#  'EmployeeNumber',
#  'EnvironmentSatisfaction',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StandardHours',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %% [markdown]
# # Target column

# %% [markdown]
# our target column is "Attrition"

# %% [markdown]
# # Exploratory Data Analysis

# %%
df["Attrition"].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %% [markdown]
# In 1470 employees records, 237 people left the company, which accounts for 16.12% of the total population

# %%
print((df.Attrition.value_counts()/len(df.index))*100)
sns.countplot(x='Attrition',data=df)
# Out:
# No     83.877551
# Yes    16.122449
# Name: Attrition, dtype: float64

# %% [markdown]
# It's Quiet imbalance dataset, where 83.87% data have attrition label has "No" and only 16.12% data has got attrition rate has "yes".

# %%
sns.countplot(x='Attrition',hue="Gender", data=df)

# %% [markdown]
# both male and female employees are lefting the job

# %%
sns.countplot(x='BusinessTravel',hue="Attrition", data=df)

# %% [markdown]
# As per this ficiton datset we see people who "Travel Rarely" are the one who have quitted more

# %%
sns.countplot(x='Department',hue="Attrition", data=df)

# %% [markdown]
# As per this ficiton datset we see employees who are from the "Research & Development Department" are the one who have quitted more

# %%
sns.countplot(x="EducationField",hue="Attrition",data=df)

# %% [markdown]
# Employees who are from Life Sciences and Medical field ,are the one who have quitted more

# %%
plt.figure(figsize=(12,5))
l=list(df['JobRole'].unique())
chart=sns.countplot(x="JobRole",hue="Attrition",data=df)
chart.set_xticklabels(labels=l,rotation=90)
# Out:
# [Text(0, 0, 'Sales Executive'),
#  Text(0, 0, 'Research Scientist'),
#  Text(0, 0, 'Laboratory Technician'),
#  Text(0, 0, 'Manufacturing Director'),
#  Text(0, 0, 'Healthcare Representative'),
#  Text(0, 0, 'Manager'),
#  Text(0, 0, 'Sales Representative'),
#  Text(0, 0, 'Research Director'),
#  Text(0, 0, 'Human Resources')]

# %% [markdown]
# Employees who are from Sales Executive field and laboratory technician ,are the one who have quitted more

# %%
sns.countplot(x="MaritalStatus",hue="Attrition",data=df)

# %% [markdown]
# Employees who are single or did not get merrie ,are the one who quitted more

# %%
sns.countplot(x="OverTime",hue="Attrition",data=df)

# %% [markdown]
# As per the Graph we get to see Employees who work overtime are the one who likely to leave the orgnisation than compared to others.

# %%
c=df.loc[:,["JobSatisfaction","Attrition"]]
c["JobSatisfaction"] =  c["JobSatisfaction"].replace({1:'Low',2:'Medium',3:'High',4:'Very High'})
sns.countplot(x="JobSatisfaction",hue="Attrition",data=c)

# %% [markdown]
# From the above Visualization we get to see that people who has job satisfaction level as "High" also has got hit attrition followed by "Low" job satisfaction level. This also indicates how the data was recorded for job satisfaction since if employee thinks it get tracked then they might shows the False postive indications.

# %%
c["JobSatisfaction"].value_counts()
# Out:
# Very High    459
# High         442
# Low          289
# Medium       280
# Name: JobSatisfaction, dtype: int64

# %%
sns.distplot(df["MonthlyIncome"])
plt.rcParams['figure.figsize']=(12,5)
plt.title("MonthlyIncome",fontsize=16)
plt.xlabel("MonthlyIncome")
plt.ylabel("density")
plt.show()

# %% [markdown]
# the monthly income is positive skewed, which means the most of employees have lower than 10000 per month income level.

# %%
sns.distplot(df["TotalWorkingYears"])
plt.rcParams['figure.figsize']=(12,5)
plt.title("TotalWorkingYears",fontsize=16)
plt.xlabel("TotalWorkingYears")
plt.ylabel("density")
plt.show()

# %% [markdown]
# from the above graph it is clear that most of employees working years at company between 1 to 10 years

# %%
import itertools
import matplotlib.pyplot as plt
import seaborn as sns

cols=['YearsAtCompany',
 'YearsInCurrentRole',
 'YearsSinceLastPromotion',
 'YearsWithCurrManager'] 
length= len(cols)
cs=["b","r","g","c"]
fig=plt.figure(figsize=(15,25))

for i,j,k in itertools.zip_longest(cols,range(length),cs):
    plt.subplot(4,2,j+1)
    ax=sns.distplot(df[i],color=k,rug=True)
    ax.set_facecolor("w")
    plt.axvline(df[i].mean(),linestyle="dashed",label="mean",color="k")
    plt.legend(loc="best")
    plt.title(i,color="navy")
    plt.xlabel("")

# %% [markdown]
# Most of employees work at company between 0 to 6 years and at current role between 0 to 4 years. working Years after last promotion at company between 0 to 2 and years with current manger at company between 0 to 4

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x="Age", y="MonthlyIncome", hue='Attrition', data=df)
plt.show()

# %% [markdown]
# Employees who are working continue with the company ,are getting hike in the monthly income. Employess who have  ages about between 43 to 48 and 52 to 56 years ,are the one who quitted job.

# %%
plt.figure(figsize=(15,7))
sns.lineplot(x="TotalWorkingYears", y="MonthlyIncome", hue='Attrition' ,data=df)
plt.show()

# %% [markdown]
# Employees who have worked 25 to 35 years at company ,are getting high salary.

# %%
a=df.groupby(['EducationField'])['MonthlyIncome'].sum().sort_values(ascending=False).reset_index()
a
# Out:
#      EducationField  MonthlyIncome
# 0     Life Sciences        3916753
# 1           Medical        3020657
# 2         Marketing        1168425
# 3  Technical Degree         760096
# 4             Other         497867
# 5   Human Resources         195511

# %%
sns.barplot(x='EducationField',y='MonthlyIncome',data=a)
plt.xlabel("EducationField",fontsize=20)
plt.ylabel("MonthlyIncome",fontsize=20)
plt.title("Monthly income all Education_Field",fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Education field of 'Life Sciences' is getting high monthly income than the other

# %%
b=df.groupby(['JobRole'])['MonthlyIncome'].sum().sort_values(ascending=False).reset_index()
b
# Out:
#                      JobRole  MonthlyIncome
# 0            Sales Executive        2257315
# 1                    Manager        1752531
# 2          Research Director        1282684
# 3     Manufacturing Director        1057795
# 4  Healthcare Representative         986268
# 5         Research Scientist         946072
# 6      Laboratory Technician         838427
# 7            Human Resources         220259
# 8       Sales Representative         217958

# %%
sns.barplot(x='JobRole',y='MonthlyIncome',data=b)
plt.xlabel("JobRole",fontsize=20)
plt.ylabel("MonthlyIncome",fontsize=20)
plt.title("Monthly income JobRole wise",fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Employees of Sales Executive are getting high salary than the other so this field's employees have bright future if they work hard

# %% [markdown]
# # correlation matrix

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10)) 
sns.heatmap(df.corr(),annot=True,linewidths=0.5,linecolor="black",fmt='.2f')

# %% [markdown]
# above Heat or corelation map tells how the features are linked to other features. we can see
#
# Job level is directly proportional to Total working years.
#
# Montly Income is directly proportional to the Total working years.
#
# Stock option is Directly proptional to Job level.
#
# Performance Rating is Directly proportional to percentage salary hike.

# %% [markdown]
# # check outliers

# %%
plt.figure(figsize=(18,14))
box = sns.boxplot(data=df)
box.set_xticklabels(labels=box.get_xticklabels(),rotation=90);

# %% [markdown]
# Monthy income has so much outliers than the others but we would not remove them because we have less data. so we will go with the outliers

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
cat_col=['Attrition',
 'BusinessTravel',
 'Department',
 'EducationField',
 'Gender',
 'JobRole',
 'MaritalStatus',
 'Over18',
 'OverTime']
for col in cat_col:
    df[col] = le.fit_transform(df[col])

# %% [markdown]
# # Onehot Encoding

# %%
df =pd.get_dummies(df,columns=['BusinessTravel',
 'Department',
 'EducationField',
 'Gender',
 'JobRole',
 'MaritalStatus',
 'Over18',
 'OverTime'])
df.head()
# Out:
#    Age  Attrition  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0   41          1       1102                 1          2              1
# 1   49          0        279                 8          1              1
# 2   37          1       1373                 2          2              1
# 3   33          0       1392                 3          4              1
# 4   27          0        591                 2          1              1
#
#    EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  ...  \
# 0               1                        2          94               3  ...
# 1               2                        3          61               2  ...
# 2               4                        4          92               2  ...
# 3               5                        4          56               3  ...
# 4               7                        1          40               3  ...
#
#    JobRole_5  JobRole_6  JobRole_7  JobRole_8  MaritalStatus_0  \
# ...

# %% [markdown]
# # Input split

# %%
X=df.drop("Attrition",axis=1)
y=df['Attrition']

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
def train(model, X, y):
    # train the model
    model.fit(X, y)
    
    # predict the training set
    pred = model.predict(X)
    
    # perform cross-validation
    cv_score = cross_val_score(model, X, y, scoring='neg_mean_squared_error', cv=5)
    cv_score = np.abs(np.mean(cv_score))
    
    print("Model Report")
    print("MSE:",mean_squared_error(y,pred))
    print("CV Score:", cv_score)

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
model = LinearRegression(normalize=True)
train(model, X, y)
coef = pd.Series(model.coef_, X.columns).sort_values()
coef.plot(kind='bar', title="Model Coefficients")
# Out:
# Model Report
# MSE: 7.812925170068027
# CV Score: 0.7422619047619048

# %%
model = Ridge(normalize=True)
train(model, X, y)
coef = pd.Series(model.coef_, X.columns).sort_values()
coef.plot(kind='bar', title="Model Coefficients")
# Out:
# Model Report
# MSE: 0.10659113354589186
# CV Score: 0.10981935232409379

# %%
model = Lasso()
train(model, X, y)
coef = pd.Series(model.coef_, X.columns).sort_values()
coef.plot(kind='bar', title="Model Coefficients")
# Out:
# Model Report
# MSE: 0.1312869488972195
# CV Score: 0.13204856065783893

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
train(model, X, y)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title="Feature Importance")
# Out:
# Model Report
# MSE: 0.0
# CV Score: 0.2122448979591837

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
train(model, X, y)
coef = pd.Series(model.feature_importances_, X.columns).sort_values(ascending=False)
coef.plot(kind='bar', title="Feature Importance")
# Out:
# Model Report
# MSE: 0.014869727891156462
# CV Score: 0.10789782312925171

# %% [markdown]
# RandomForestRegressor classifier has less MSE and CV score so this is best model let's save it

# %% [markdown]
# # Serialization

# %%
import joblib
joblib.dump(RandomForestRegressor(),"hrdatasetproject.pkl")
# Out:
# ['hrdatasetproject.pkl']
